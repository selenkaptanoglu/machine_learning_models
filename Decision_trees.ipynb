# %% [markdown]
# <a href="https://colab.research.google.com/github/selenkaptanoglu/machine_learning_models/blob/main/Decision_trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import plot_tree

# %%
dataset = pd.read_csv("titanic.csv")
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         1       1    0  38.0      1      0  71.2833         0
# 1         1       1    0  35.0      1      0  53.1000         2
# 2         0       1    1  54.0      0      0  51.8625         2
# 3         1       3    0   4.0      1      1  16.7000         2
# 4         1       1    0  58.0      0      0  26.5500         2

# %%
X = dataset.drop("Survived", axis=1)
y = dataset.loc[:,"Survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
decisiontree = DecisionTreeClassifier()
randomforest = RandomForestClassifier()

# %%
decisiontree.fit(X_train, y_train)
randomforest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
fig = plt.figure(figsize=(10,10))
plot_tree(decisiontree,
          max_depth=2,
          feature_names=X.columns,
          filled=True,
          impurity=False,
          rounded=True,
          precision=1)

plt.show()

# %%
decisiontree_pred = decisiontree.predict(X_test)
randomforest_pred = randomforest.predict(X_test)

# %%
print(classification_report(y_test, decisiontree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        20
#            1       0.91      0.89      0.90        35
#
#     accuracy                           0.87        55
#    macro avg       0.86      0.87      0.86        55
# weighted avg       0.87      0.87      0.87        55

# %%
print(classification_report(y_test, randomforest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.55      0.67        20
#            1       0.79      0.94      0.86        35
#
#     accuracy                           0.80        55
#    macro avg       0.82      0.75      0.76        55
# weighted avg       0.81      0.80      0.79        55
